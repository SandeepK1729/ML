# %%
import pandas as pd
import numpy as np

# %%
s1=pd.read_csv("stroke.csv")

# %%
s1.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
s2=s1.copy()

# %%
bmi_df=pd.DataFrame(s2['bmi'])

# %%
bmi_df_fil=bmi_df.fillna(bmi_df.mean())

# %%
dict1={'bmi':'bmi_m'}

# %%
bmi_df_fil.rename(columns=dict1, inplace=True)

# %%
s3=s2.drop('bmi', axis=1)

# %%
s4=s3.join(bmi_df_fil)

# %%
s4.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   smoking_status  stroke  \
# 0        Private          Urban             228.69  formerly smoked       1
# 1  Self-employed          Rural             202.21     never smoked       1
# 2        Private          Rural             105.92     never smoked       1
# 3        Private          Urban             171.23           smokes       1
# 4  Self-employed          Rural             174.12     never smoked       1
#
#        bmi_m
# 0  36.600000
# 1  28.893237
# 2  32.500000
# 3  34.400000
# 4  24.000000

# %%
s5=pd.get_dummies(s4,['gender','ever_married','work_type','Residence_type','smoking_status'])

# %%
s5
# Out:
#          id    age  hypertension  heart_disease  avg_glucose_level  stroke  \
# 0      9046  67.00             0              1             228.69       1
# 1     51676  61.00             0              0             202.21       1
# 2     31112  80.00             0              1             105.92       1
# 3     60182  49.00             0              0             171.23       1
# 4      1665  79.00             1              0             174.12       1
# 5     56669  81.00             0              0             186.21       1
# 6     53882  74.00             1              1              70.09       1
# 7     10434  69.00             0              0              94.39       1
# 8     27419  59.00             0              0              76.15       1
# 9     60491  78.00             0              0              58.57       1
# 10    12109  81.00             1              0              80.43       1
# ...

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
Clst=AgglomerativeClustering(n_clusters=3)

# %%
y=s5.stroke

# %%
x=s5.drop('stroke',axis=1)

# %%
x
# Out:
#          id    age  hypertension  heart_disease  avg_glucose_level      bmi_m  \
# 0      9046  67.00             0              1             228.69  36.600000
# 1     51676  61.00             0              0             202.21  28.893237
# 2     31112  80.00             0              1             105.92  32.500000
# 3     60182  49.00             0              0             171.23  34.400000
# 4      1665  79.00             1              0             174.12  24.000000
# 5     56669  81.00             0              0             186.21  29.000000
# 6     53882  74.00             1              1              70.09  27.400000
# 7     10434  69.00             0              0              94.39  22.800000
# 8     27419  59.00             0              0              76.15  28.893237
# 9     60491  78.00             0              0              58.57  24.200000
# 10    12109  81.00             1              0              80.43  29.700000
# ...
